# %% [markdown]
# # Explore here
#
# It's recommended to use this notebook for exploration purposes.
#
# For example:
#
# 1. You could import the CSV generated by python into your notebook and explore it.
# 2. You could connect to your database using `pandas.read_sql` from this notebook and explore it.

# %%
# Example reading the SQL database from here

# from dotenv import load_dotenv
# from sqlalchemy import create_engine
# import pandas as pd

# # load the .env file variables
# load_dotenv()

# connection_string = f"mysql+pymysql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}/{os.getenv('DB_NAME')}?autocommit=true"
# engine = create_engine(connection_string)
# engine.connect()

# dataframe = pd.read_sql("Select * from books;", engine)
# print(dataframe.describe())

# %%
# Example importing the CSV here

# dataframe = pd.read_csv('../path/to/file.csv')
# dataframe.describe()

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import sqlite3

# %%
url = " https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue"
html_data = requests.get(url).text
# print(html_data)

# %%
requests.get(url).text
# Out:
# '\r\n<!DOCTYPE html>\r\n<!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\r\n<!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->\r\n<!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->\r\n<!--[if gt IE 8]><!--> <html class="no-js"> <!--<![endif]-->\r\n    <head>\r\n        <meta charset="utf-8">\r\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\r\n\t\t<link rel="canonical" href="https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue" />\r\n\t\t<title>Tesla Revenue 2010-2022 | TSLA | MacroTrends</title>\r\n\t\t<meta name="description" content="Tesla annual/quarterly revenue history and growth rate from 2010 to 2022. Revenue can be defined as the amount of money a company receives from its customers in exchange for the sales of goods or services.  Revenue is the top line item on an income statement from which all costs and expenses are subtracted to arrive at net income.    \r\n\t\t\t\t\r\n\t\t\t\t&lt;ul style=\'margin-top:10px;\'&gt;\r\n\t\t\t\t&lt;li&gt;Tesla revenue for the quarter ending March 31, 2022 was &lt;strong&gt;$18.756B&lt;/strong&gt;, a &lt;strong&gt;80.54% increase&lt;/strong&gt; year-over-year.&lt;/li&gt;\r\n\t\t\t\t&lt;li&gt;Tesla revenue for the twelve months ending March 31, 2022 was &lt;strong&gt;$62.190B&lt;/strong&gt;, a &lt;strong&gt;73.04% increase&lt;/strong&gt; year-over-year.&lt;/li&gt;\r\n\t\t\t\t&lt;li&gt;Tesla annual revenue for 2021 was &lt;strong&gt;$53.823B&lt;/strong&gt;, a &lt;strong&gt;70.67% increase&lt;/strong&gt; from 2020.&lt;/li&gt;\r\n\t\t\t\t&lt;li&gt;Tesla annual revenue for 2020 was &lt;strong&gt;$31.536B&lt;/strong&gt;, a &lt;strong&gt;28.31% increase&lt;/strong&gt; from 2019.&lt;/li&gt;\r\n\t\t\t\t&lt;li&gt;Tesla annual revenue for 2019 was &lt;strong&gt;$24.578B&lt;/strong&gt;, a &lt;strong&gt;14.52% increase&lt;/strong&gt; from 2018.&lt;/li&gt;\r\n\t\t\t\t&lt;/ul&gt;" />\r\n\t\t<meta name="robots" content="" />\r\n\t\t\t\t\r\n\t\t<link rel="shortcut icon" href="/assets/images/icons/FAVICON/macro-trends_favicon.ico" type="image/x-icon">\r\n\r\n\t\t<meta name="msvalidate.01" content="1228954C688F5907894001CD8E5E624B" />\r\n\t\t<meta name="google-site-verification" content="6MnD_3iDtAP1ZyoGK1YMyVIVck4r5Ws80I9xD3ue4_A" />\r\n\r\n\t\t<!-- Load in Roboto Font -->\r\n\t\t<link rel=\'stylesheet\' href=\'https://fonts.googleapis.com/css?family=Roboto:400,600,700\'>\r\n\r\n\t\t<!-- Bootstrap -->\r\n\t\t<link rel="stylesheet" href="//maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css"> <!--for Bootstrap CDN version-->\r\n\t\t<link rel="stylesheet" href="//maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap-theme.min.css">\r\n\r\n\t\t<!-- Font Awesome -->\r\n\t\t<link rel="stylesheet" href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"> <!--for Font Awesome CDN version-->\r\n    \t\t\r\n\t\t<!-- Jquery, Bootstrap and Menu Javascript -->\t\r\n\t\t<script src="//code.jquery.com/jquery-1.12.4.min.js" integrity="sha256-ZosEbRLbNQzLpnKIkEdrPv7lOy9C27hHQ+Xp8a4MxAQ=" crossorigin="anonymous"></script>\r\n\t\t<script src="//maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js"></script>\r\n\t\t\t\t\r\n\t\t<!-- Modernizr for cross-browser support -->\t\t\r\n\t\t<script type="text/javascript" src="/assets/javascript/modernizr-2.6.2-respond-1.1.0.min.js"></script>\r\n\r\n\t\t<!-- Latest compiled and minified CSS -->\r\n\t\t<link rel="stylesheet" href="//www.fuelcdn.com/fuelux/3.13.0/css/fuelux.min.css">\r\n\r\n\t\t<!-- Latest compiled and minified JavaScript -->\r\n\t\t<script src="//www.fuelcdn.com/fuelux/3.13.0/js/fuelux.min.js"></script>\r\n\t\t\r\n\t\t\r\n\t\t <!-- Twitter Card data -->\r\n\t\t  <meta name="twitter:card" content="summary_large_image">\r\n\t\t  <meta name="twitter:site" content="@tmacrotrends">\r\n\t\t  <meta name="twitter:title" content="Tesla Revenue 2010-2022 | TSLA">\r\n\t\t  <meta name="twitter:description" content="Tesla annual/quarterly revenue ...

# %%
soup = BeautifulSoup(html_data,"html.parser")
# print(soup)

# %%
tables = soup.find_all('table')

for index, table in enumerate(tables):
    if ("Tesla Quarterly Revenue" in str(table)):
        table_index = index

#create a dataframe        
tesla_revenue = pd.DataFrame(columns=["Date", "Revenue"])

for row in tables[table_index].tbody.find_all("tr"):
    col = row.find_all("td")
    if (col != []):
        Date = col[0].text
        Revenue = col[1].text.replace("$", "").replace(",", "")
        tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# Out:
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)
# /tmp/ipykernel_1090/1706829602.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tesla_revenue = tesla_revenue.append({"Date":Date, "Revenue":Revenue}, ignore_index=True)

# %%
"""
tesla_revenue=pd.read_html(url, match="Tesla Quarterly Revenue", flavor='bs4')[0]
tesla_revenue = tesla_revenue.rename(columns={"Tesla Quarterly Revenue(Millions of US $)":"Date","Tesla Quarterly Revenue(Millions of US $).1":"Revenue"}) #Rename df columns to 'Date' and 'Revenue'
tesla_revenue["Revenue"] = tesla_revenue['Revenue'].str.replace(',|\$',"") # remove the comma and dollar sign from the 'Revenue' column
tesla_revenue.head()
"""
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /workspace/web-scraping-project-tutorial/src/explore.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://jgayosof-webscrapingpro-pn4b79rxy6s.ws-us47.gitpod.io/workspace/web-scraping-project-tutorial/src/explore.ipynb#ch0000009vscode-remote?line=0'>1</a> tesla_revenue=pd.read_html(url, match="Tesla Quarterly Revenue", flavor='bs4')[0]
#       <a href='vscode-notebook-cell://jgayosof-webscrapingpro-pn4b79rxy6s.ws-us47.gitpod.io/workspace/web-scraping-project-tutorial/src/explore.ipynb#ch0000009vscode-remote?line=1'>2</a> tesla_revenue = tesla_revenue.rename(columns={"Tesla Quarterly Revenue(Millions of US $)":"Date","Tesla Quarterly Revenue(Millions of US $).1":"Revenue"}) #Rename df columns to 'Date' and 'Revenue'
#       <a href='vscode-notebook-cell://jgayosof-webscrapingpro-pn4b79rxy6s.ws-us47.gitpod.io/workspace/web-scraping-project-tutorial/src/explore.ipynb#ch0000009vscode-remote?line=2'>3</a> tesla_revenue["Revenue"] = tesla_revenue['Revenue'].str.replace(',|\$',"") # remove the comma and dollar sign from the 'Revenue' column
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1108'>1109</a> validate_header_arg(header)
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1110'>1111</a> io = stringify_path(io)
# -> <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1112'>1113</a> return _parse(
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1113'>1114</a>     flavor=flavor,
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1114'>1115</a>     io=io,
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1115'>1116</a>     match=match,
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1116'>1117</a>     header=header,
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1117'>1118</a>     index_col=index_col,
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1118'>1119</a>     skiprows=skiprows,
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1119'>1120</a>     parse_dates=parse_dates,
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1120'>1121</a>     thousands=thousands,
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1121'>1122</a>     attrs=attrs,
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1122'>1123</a>     encoding=encoding,
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1123'>1124</a>     decimal=decimal,
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1124'>1125</a>     converters=converters,
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1125'>1126</a>     na_values=na_values,
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1126'>1127</a>     keep_default_na=keep_default_na,
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1127'>1128</a>     displayed_only=displayed_only,
#    <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=1128'>1129</a> )
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py:915, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=912'>913</a> retained = None
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=913'>914</a> for flav in flavor:
# --> <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=914'>915</a>     parser = _parser_dispatch(flav)
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=915'>916</a>     p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=917'>918</a>     try:
#
# File ~/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py:864, in _parser_dispatch(flavor)
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=861'>862</a> if flavor in ("bs4", "html5lib"):
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=862'>863</a>     if not _HAS_HTML5LIB:
# --> <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=863'>864</a>         raise ImportError("html5lib not found, please install it")
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=864'>865</a>     if not _HAS_BS4:
#     <a href='file:///home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages/pandas/io/html.py?line=865'>866</a>         raise ImportError("BeautifulSoup4 (bs4) not found, please install it")
#
# ImportError: html5lib not found, please install it

# %%
tesla_revenue = tesla_revenue[tesla_revenue['Revenue'] != ""]
print(tesla_revenue)
# Out:
#           Date Revenue
# 0   2022-03-31   18756
# 1   2021-12-31   17719
# 2   2021-09-30   13757
# 3   2021-06-30   11958
# 4   2021-03-31   10389
# 5   2020-12-31   10744
# 6   2020-09-30    8771
# 7   2020-06-30    6036
# 8   2020-03-31    5985
# 9   2019-12-31    7384
# 10  2019-09-30    6303
# 11  2019-06-30    6350
# 12  2019-03-31    4541
# 13  2018-12-31    7226
# 14  2018-09-30    6824
# 15  2018-06-30    4002
# 16  2018-03-31    3409
# 17  2017-12-31    3288
# 18  2017-09-30    2985
# 19  2017-06-30    2790
# 20  2017-03-31    2696
# 21  2016-12-31    2285
# 22  2016-09-30    2298
# 23  2016-06-30    1270
# 24  2016-03-31    1147
# 25  2015-12-31    1214
# 26  2015-09-30     937
# 27  2015-06-30     955
# 28  2015-03-31     940
# 29  2014-12-31     957
# 30  2014-09-30     852
# 31  2014-06-30     769
# 32  2014-03-31     621
# 33  2013-12-31     615
# 34  2013-09-30     431
# 35  2013-06-30     405
# 36  2013-03-31     562
# 37  2012-12-31     306
# 38  2012-09-30      50
# 39  2012-06-30      27
# 40  2012-03-31      30
# 41  2011-12-31      39
# 42  2011-09-30      58
# 43  2011-06-30      58
# 44  2011-03-31      49
# 45  2010-12-31      36
# 46  2010-09-30      31
# 47  2010-06-30      28
# 48  2010-03-31      21
# 50  2009-09-30      46
# 51  2009-06-30      27

# %%
records = tesla_revenue.to_records(index=False)
print(records)
# Out:
# [('2022-03-31', '18756') ('2021-12-31', '17719') ('2021-09-30', '13757')
#  ('2021-06-30', '11958') ('2021-03-31', '10389') ('2020-12-31', '10744')
#  ('2020-09-30', '8771') ('2020-06-30', '6036') ('2020-03-31', '5985')
#  ('2019-12-31', '7384') ('2019-09-30', '6303') ('2019-06-30', '6350')
#  ('2019-03-31', '4541') ('2018-12-31', '7226') ('2018-09-30', '6824')
#  ('2018-06-30', '4002') ('2018-03-31', '3409') ('2017-12-31', '3288')
#  ('2017-09-30', '2985') ('2017-06-30', '2790') ('2017-03-31', '2696')
#  ('2016-12-31', '2285') ('2016-09-30', '2298') ('2016-06-30', '1270')
#  ('2016-03-31', '1147') ('2015-12-31', '1214') ('2015-09-30', '937')
#  ('2015-06-30', '955') ('2015-03-31', '940') ('2014-12-31', '957')
#  ('2014-09-30', '852') ('2014-06-30', '769') ('2014-03-31', '621')
#  ('2013-12-31', '615') ('2013-09-30', '431') ('2013-06-30', '405')
#  ('2013-03-31', '562') ('2012-12-31', '306') ('2012-09-30', '50')
#  ('2012-06-30', '27') ('2012-03-31', '30') ('2011-12-31', '39')
#  ('2011-09-30', '58') ('2011-06-30', '58') ('2011-03-31', '49')
#  ('2010-12-31', '36') ('2010-09-30', '31') ('2010-06-30', '28')
#  ('2010-03-31', '21') ('2009-09-30', '46') ('2009-06-30', '27')]

# %%
# transformo array a lista
list_of_tuples = list(records)
print(list_of_tuples)
# Out:
# [('2022-03-31', '18756'), ('2021-12-31', '17719'), ('2021-09-30', '13757'), ('2021-06-30', '11958'), ('2021-03-31', '10389'), ('2020-12-31', '10744'), ('2020-09-30', '8771'), ('2020-06-30', '6036'), ('2020-03-31', '5985'), ('2019-12-31', '7384'), ('2019-09-30', '6303'), ('2019-06-30', '6350'), ('2019-03-31', '4541'), ('2018-12-31', '7226'), ('2018-09-30', '6824'), ('2018-06-30', '4002'), ('2018-03-31', '3409'), ('2017-12-31', '3288'), ('2017-09-30', '2985'), ('2017-06-30', '2790'), ('2017-03-31', '2696'), ('2016-12-31', '2285'), ('2016-09-30', '2298'), ('2016-06-30', '1270'), ('2016-03-31', '1147'), ('2015-12-31', '1214'), ('2015-09-30', '937'), ('2015-06-30', '955'), ('2015-03-31', '940'), ('2014-12-31', '957'), ('2014-09-30', '852'), ('2014-06-30', '769'), ('2014-03-31', '621'), ('2013-12-31', '615'), ('2013-09-30', '431'), ('2013-06-30', '405'), ('2013-03-31', '562'), ('2012-12-31', '306'), ('2012-09-30', '50'), ('2012-06-30', '27'), ('2012-03-31', '30'), ('2011-12-31', '39'), ('2011-09-30', '58'), ('2011-06-30', '58'), ('2011-03-31', '49'), ('2010-12-31', '36'), ('2010-09-30', '31'), ('2010-06-30', '28'), ('2010-03-31', '21'), ('2009-09-30', '46'), ('2009-06-30', '27')]

# %%
# Crea la base
connection = sqlite3.connect('Tesla.db')

c = connection.cursor()

# Create table
c.execute('''CREATE TABLE IF NOT EXISTS revenue (Date, Revenue)''')

# %%
# Insert data
c.executemany('INSERT INTO revenue VALUES (?,?)', list_of_tuples)
# Save (commit) the changes
connection.commit()

# %%
for row in c.execute('SELECT * FROM revenue'):
    print(row)
# Out:
# ('2022-03-31', '18756')
# ('2021-12-31', '17719')
# ('2021-09-30', '13757')
# ('2021-06-30', '11958')
# ('2021-03-31', '10389')
# ('2020-12-31', '10744')
# ('2020-09-30', '8771')
# ('2020-06-30', '6036')
# ('2020-03-31', '5985')
# ('2019-12-31', '7384')
# ('2019-09-30', '6303')
# ('2019-06-30', '6350')
# ('2019-03-31', '4541')
# ('2018-12-31', '7226')
# ('2018-09-30', '6824')
# ('2018-06-30', '4002')
# ('2018-03-31', '3409')
# ('2017-12-31', '3288')
# ('2017-09-30', '2985')
# ('2017-06-30', '2790')
# ('2017-03-31', '2696')
# ('2016-12-31', '2285')
# ('2016-09-30', '2298')
# ('2016-06-30', '1270')
# ('2016-03-31', '1147')
# ('2015-12-31', '1214')
# ('2015-09-30', '937')
# ('2015-06-30', '955')
# ('2015-03-31', '940')
# ('2014-12-31', '957')
# ('2014-09-30', '852')
# ('2014-06-30', '769')
# ('2014-03-31', '621')
# ('2013-12-31', '615')
# ('2013-09-30', '431')
# ('2013-06-30', '405')
# ('2013-03-31', '562')
# ('2012-12-31', '306')
# ('2012-09-30', '50')
# ('2012-06-30', '27')
# ('2012-03-31', '30')
# ('2011-12-31', '39')
# ('2011-09-30', '58')
# ('2011-06-30', '58')
# ('2011-03-31', '49')
# ('2010-12-31', '36')
# ('2010-09-30', '31')
# ('2010-06-30', '28')
# ('2010-03-31', '21')
# ('2009-09-30', '46')
# ('2009-06-30', '27')
# ('2022-03-31', '18756')
# ('2021-12-31', '17719')
# ('2021-09-30', '13757')
# ('2021-06-30', '11958')
# ('2021-03-31', '10389')
# ('2020-12-31', '10744')
# ('2020-09-30', '8771')
# ('2020-06-30', '6036')
# ('2020-03-31', '5985')
# ('2019-12-31', '7384')
# ('2019-09-30', '6303')
# ('2019-06-30', '6350')
# ('2019-03-31', '4541')
# ('2018-12-31', '7226')
# ('2018-09-30', '6824')
# ('2018-06-30', '4002')
# ('2018-03-31', '3409')
# ('2017-12-31', '3288')
# ('2017-09-30', '2985')
# ('2017-06-30', '2790')
# ('2017-03-31', '2696')
# ('2016-12-31', '2285')
# ('2016-09-30', '2298')
# ('2016-06-30', '1270')
# ('2016-03-31', '1147')
# ('2015-12-31', '1214')
# ('2015-09-30', '937')
# ('2015-06-30', '955')
# ('2015-03-31', '940')
# ('2014-12-31', '957')
# ('2014-09-30', '852')
# ('2014-06-30', '769')
# ('2014-03-31', '621')
# ('2013-12-31', '615')
# ('2013-09-30', '431')
# ('2013-06-30', '405')
# ('2013-03-31', '562')
# ('2012-12-31', '306')
# ('2012-09-30', '50')
# ('2012-06-30', '27')
# ('2012-03-31', '30')
# ('2011-12-31', '39')
# ('2011-09-30', '58')
# ('2011-06-30', '58')
# ('2011-03-31', '49')
# ('2010-12-31', '36')
# ('2010-09-30', '31')
# ('2010-06-30', '28')
# ('2010-03-31', '21')
# ('2009-09-30', '46')
# ('2009-06-30', '27')
